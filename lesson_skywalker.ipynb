# %% [markdown]
# # PyTorch tensors
#
# - For today, the same as numpy arrays
#     - But can run on a GPU

# %%
# Pytorch
import torch

# %%
a = torch.tensor([1,2,3])
b = torch.tensor([4,5,6])
a + b
# Out:
# tensor([5, 7, 9])

# %%
c = torch.stack([a,b])
(c, c.shape)
# Out:
# (tensor([[1, 2, 3],
#          [4, 5, 6]]),
#  torch.Size([2, 3]))

# %%
torch.cuda.is_available()
# Out:
# True

# %%
c.is_cuda
# Out:
# False

# %%
c_gpu = c.cuda()
(c_gpu, c.is_cuda)
# Out:
# (tensor([[1, 2, 3],
#          [4, 5, 6]], device='cuda:0'),
#  False)
